# %%
import pandas as pd

# %%
# get bricklink data

df_sets_bricklink = pd.read_csv('sets-bricklink.tsv', sep='\t')
df_instructions = pd.read_csv('instructions-bricklink.tsv', sep='\t')
df_boxes = pd.read_csv('boxes-bricklink.tsv', sep='\t')

# %%
# merge brickset set data
# Out:
#        Category ID                                    Category Name    Number  \
# 0              179                            Racers / Drome Racers    8470-1
# 1               36                             Technic / RoboRiders    1292-1
# 2              277                                  Legoland / Fire     691-1
# 3              277                                 Legoland / Space     367-1
# 4              422             Universal Building Set / Basic Model    2121-1
# ...            ...                                              ...       ...
# 15539          390  Holiday & Event / Advent Sub-Set / Harry Potter  75964-23
# 15540          390  Holiday & Event / Advent Sub-Set / Harry Potter  75964-24
# 15541          390  Holiday & Event / Advent Sub-Set / Harry Potter  75964-25
# 15542           65      Star Wars / BOOST / Star Wars Episode 4/5/6   75522-1
# 15543          976    LEGO Brand / LEGO Brand Store / Monthly Model   40329-1
#
#                                                     Name Year Released  \
# 0                                        Slammer G-Force          2002
# 1                                            Frost Flyer          2000
# 2                                      Rescue Helicopter          1974
# 3                                           Moon Landing          1975
# 4       Jack in the Box Promotional Set: Stomper polybag          1997
# ...                                                  ...           ...
# 15539  Advent Calendar 2019, Harry Potter (Day 22) - ...          2019
# 15540  Advent Calendar 2019, Harry Potter (Day 23) - ...          2019
# 15541  Advent Calendar 2019, Harry Potter (Day 24) - ...          2019
# 15542                 Mini Boost Droid Commander polybag          2019
# 15543  Monthly Mini Model Build Set - 2019 09 Septemb...          2019
#
#       Weight (in Grams)       Dimensions
# 0                     ?        ? x ? x ?
# 1                     ?        ? x ? x ?
# 2                     ?     20 x 6.5 x 4
# 3                   134  35.1 x 19.9 x 5
# 4                     ?        ? x ? x ?
# ...                 ...              ...
# 15539                 ?  8.6 x 9.2 x 0.5
# 15540                 ?     11 x 9 x 1.2
# 15541                 ?    11 x 10 x 1.4
# 15542                 ?        ? x ? x ?
# 15543                 ?        ? x ? x ?
#
# [15544 rows x 7 columns]
